# %% [markdown]
# # SECTION 15. Support Vector Machines SVM

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')

# %%
label_a = np.random.normal(6, 2, size=(50, 2))

# %%
label_b = np.random.normal(-6, 2, size=(50, 2))

# %%
plt.scatter(*zip(*label_a))
plt.scatter(*zip(*label_b))

# %%
label_a_x = label_a[:, 0]
label_b_x = label_b[:, 0]

# %%
def f(x, w, b):
    return w * x - b

# %%
w_and_b = []
for i in range(100): 
    w, b = (np.random.random(size=(1, 2)) * 10 - 5)[0]
    if np.max(f(label_a_x, w, b)) <= -1 and np.min(f(label_b_x, w, b)) >= 1:
        print(w, b)
        w_and_b.append((w, b))
# Out:
# -1.4530144201134854 -3.271520666758713
# -3.8309264132894603 -1.052593832108788
# -2.931348424016127 0.2959472090311781
# -3.0974175293995962 1.9475987386972022
# -2.0924222517036526 -0.09297478908662526
# -2.6418720473409474 -0.534121067201462
# -4.141396080664351 1.7919035133924632
# -2.4390226038569516 -3.465162472783888
# -4.227327140991557 2.8320872124842964
# -3.8630717357323063 -1.801941463155543
# -3.368931849618008 -2.2952299180057323
# -4.6775230227237765 -3.0284025053881947
# -2.6022403337754496 -0.5158769343960854
# -4.972455813911157 -1.4605866452383784
# -1.6735896500962708 -3.651800425843952
# -3.5210623031446797 2.8400070152377133
# -2.3147667224414423 2.733554790265482
# -3.71916336135101 4.091402097645842
# -0.6204845999020332 -0.40948291110358603
# -4.740826393962435 -2.5291538871316344
# -3.620881529845754 4.313868564804599
# -2.4866214400779327 -3.096095256854131
# -3.544718136538474 -2.301512370312806
# -4.875412233360063 0.3324187567497594
# -3.5067288808773567 3.991448585455549
# -1.6984623296512513 1.1887845855320105
# -3.7928377646639335 3.0110627065307902
# -3.236372206737772 -4.1549345071494415
# -1.9210383693705668 0.8319604683965478
# -2.60892406177918 -1.8855971287050668
# -2.266350358293796 -2.7901930758770144
# -3.0194418333276287 -0.26388093310723093
# -3.6891152867214725 -1.9749453513468165
# -4.55531973166678 0.8392263539701927

# %%
plt.scatter(*zip(*label_a))
plt.scatter(*zip(*label_b))

for w, b in w_and_b:
    x = np.concatenate((label_a_x, label_b_x))
    plt.plot(x, f(x, w, b))

# %%
plt.scatter(*zip(*label_a))
plt.scatter(*zip(*label_b))

w, b = sorted(w_and_b, key=lambda t: abs(t[0]))[0]
x = np.concatenate((label_a_x, label_b_x))
plt.plot(x, f(x, w, b))
