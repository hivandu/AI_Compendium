# %% [markdown]
# # SECTION 25, matplotlib

# %%
# Import module
import matplotlib.pyplot as plt
from matplotlib import font_manager
from matplotlib.font_manager import FontProperties
from pylab import mpl

# set the chinese
mpl.rcParams['font.sans-serif'] = ['SimHei'] 
mpl.rcParams['axes.unicode_minus'] = False

plt.style.use('default')
# This code will display images when running in Jupyter
# %matplotlib inline

import numpy as np
import random

# %%
# Pass x and y to plot the graph
plt.plot([1,0,9],[4,5,6])
# Display the graph when executing the program
plt.show()

# %%
# Draw a line chart
x = range(1, 8) # x-axis positions
y = [17, 17, 18, 15, 11, 11, 13]
# Pass x and y to plot the graph
plt.plot(x, y, color='red', alpha=0.5, linestyle='--', linewidth=3, marker='o', markersize='10', markeredgecolor='blue', markeredgewidth=3)
plt.show()

# %%
x = range(2, 26, 2) # x-axis positions
y = [random.randint(15, 30) for i in x]

# Set x-axis ticks
# plt.xticks(x)
# plt.xticks(range(1, 25))
# Set y-axis ticks
# plt.yticks(y)
# plt.yticks(range(min(y), max(y)+1))

# Construct x-axis tick labels
x_ticks_label = ["{}:00".format(i) for i in x]
# Rotate labels by 45 degrees
plt.xticks(x, x_ticks_label, rotation=45)

# Construct y-axis tick labels
y_ticks_label = ["{}℃".format(i) for i in range(min(y), max(y)+1)]
plt.yticks(range(min(y), max(y)+1), y_ticks_label)

# Set figure size
# plt.figure(figsize=(20, 8), dpi=80)
plt.plot(x, y)
plt.show()
# Save the figure
# plt.savefig('./data/img/t1.png')

# %%
x = range(0, 120)
y = [random.randint(10, 30) for i in range(120)]

plt.figure(figsize=(20, 8), dpi=80)
plt.plot(x, y)

# Set font and labels
plt.xlabel('time')
plt.ylabel('number')

# Set title
plt.title('Beats per minute', color='red')

plt.show()

# %%
# Sales data comparison
y1 = [20,10,10,20,40,30,40,40,50,60,50,40]
y2 = [10,30,20,30,40,20,10,30,30,80,30,20]
x = range(1, 13)

# Set figure
plt.figure(figsize=(20, 8), dpi=80)

plt.plot(x, y1, color='orange', label="Hivan")
plt.plot(x, y2, color='green', label='colleague')

# Set x-axis ticks
xtick_labels = ['{} Mon'.format(i) for i in x]

plt.xticks(x, xtick_labels, rotation=45)

# Draw grid
plt.grid(alpha=0.4) # Grid can also have styles; here, the transparency is 0.4

# Add legend
# Set position loc: upper left, lower left, center left, upper center
plt.legend(loc='upper right')

plt.show()

# %%
# Multiple subplots
x = np.arange(1, 100)
fig = plt.figure(figsize=(20, 10), dpi=80)

# Subplot 1
ax1 = fig.add_subplot(2,2,1)
ax1.plot(x, x)
# Subplot 2
ax2 = fig.add_subplot(2,2,2)
ax2.plot(x, x**2)
ax2.grid(color='r', linestyle='--', linewidth=1, alpha=0.3)
# Subplot 3
ax3 = fig.add_subplot(2,2,3)
ax3.plot(x, np.log(x))

plt.show()

# %%
# Set axis limits
x = np.arange(-10, 11, 1)
y = x ** 2
plt.plot(x, y)

# plt.xlim([-5,5])

# Adjust only one side
# plt.xlim(xmin=-4)
# plt.xlim(xmax=4)

plt.ylim(ymin=0)
plt.xlim(xmin=0)

plt.show()

# %%
# Change the default display of axis
y = range(0, 14, 2)
x = [-3, -2, -1, 0, 1, 2, 3]
plt.figure(figsize=(20,8), dpi=80)

# Get current plot's axes
ax = plt.gca()

# Set the borders of the graph
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('blue')
ax.spines['left'].set_color('red')

# Set the position of the bottom border to the y-axis 0 position
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))

plt.plot(x, y)
plt.show()

# %%
# Draw scatter plot
y = [11,17,16,11,12,11,12,6,6,7,8,9,12,15,14,17,18,21,16,17,20,14,15,15,15,19,21,22,22,22,23]
x = range(1,32)

plt.figure(figsize=(20,8), dpi=80)
# Use scatter to draw scatter plot
plt.scatter(x, y, label='March')

_xticks_labels = ['March {}'.format(i) for i in x]

plt.xticks(x[::3], _xticks_labels[::3], rotation=45)
plt.xlabel('date')
plt.ylabel('℃')

# Legend
plt.legend()

plt.show()

# %%
mpl.rcParams['font.sans-serif'] = ['SimHei'] # Default font
mpl.rcParams['axes.unicode_minus'] = False # Fixes the issue where the minus sign '-' is not displayed correctly in saved images

a = ['消失的她','碟中谍 7:致命清算','芭比','八角笼中','茶啊二中','热烈','长安三万里','巨齿鲨 2:深渊','封神第一部','孤注一掷']
b = ['35.22','3.46','2.47','21.92','3.66','8.69','17.56','7.53','22.36','26.48']

plt.figure(figsize=(20,8), dpi=80)
rects = plt.bar(range(len(a)), [float(i) for i in b], width=0.3, color=['r','g','b','r','g','b','r','g','b','r'])
plt.xticks(range(len(a)), a)
plt.yticks(range(0,51,5), range(0,51,5))

# Add annotations (centered horizontally)
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x()+rect.get_width() / 2, height+1, str(height), ha='center')

plt.show()

# %%
mpl.rcParams['font.sans-serif'] = ['SimHei'] # Default font
mpl.rcParams['axes.unicode_minus'] = False # Fixes the issue where the minus sign '-' is not displayed correctly in saved images

# Horizontal bar chart
a = ['消失的她','碟中谍 7:致命清算','芭比','八角笼中','茶啊二中','热烈','长安三万里','巨齿鲨 2:深渊','封神第一部','孤注一掷']
b = ['35.22','3.46','2.47','21.92','3.66','8.69','17.56','7.53','22.36','26.48']

plt.figure(figsize=(20,8), dpi=80)
rects = plt.barh(range(len(a)), [float(i) for i in b], height=0.5, color=['r','g','b','r','g','b','r','g','b','r'])
plt.xticks(range(0,51,5), range(0,51,5))
plt.yticks(range(len(a)), a, rotation=45)

# Add annotations (centered vertically)
for rect in rects:
    width = rect.get_width()
    plt.text(width+1, rect.get_y()+0.5/2, str(width)+' 亿', va='center')

plt.show()

# %%
# Multiple bars side by side
index = np.arange(4)
BJ = [50,55,53,60]
SH = [44,66,55,41]
# Side by side bars
plt.bar(index, BJ, width=0.3)
plt.bar(index+0.3, SH, width=0.3, color='green')

plt.xticks(index+0.3/2, index)
plt.show()

# %%
# 250 movies, histogram of movie durations
times = [131,98,125,131,124,139,131,117,128,108,135,138,131,102,107,114,119,128,121,142,127,130,124,101,110,116,117,110,128,128,115,99,95,138,117,111,78,132,124,113,150,110,117,136,126,134,95,144,105,126,130,126,130,126,116,123,106,112,138,123,99,136,123,117,119,105,137,123,128,125,104,109,134,125,127,105,120,107,129,116,108,132,103,136,118,102,120,114,105,115,132,145,119,121,112,139,125,138,109,132,134,156,106,117,127,144,139,139,119,140,83,110,102,123,107,143,115,136,118,139,123,112,118,125,109,119,133,112,114,122,109,106,123,116,131,127,115,118,112,135,115,146,137,116,103,144,83,123,111,110,111,100,154,136,100,118,119,133,134,106,129,126,110,111,109,141,120,117,106,149,122,122,110,118,127,121,114,125,126,114,140,103,130,141,117,106,114,121,114,133,137,92,121,112,146,97,137,105,98,117,112,81,97,139,113,134,106,144,110,137,137,111,104,117,100,111,101,110,105,129,137,112,120,113,133,112,83,94,146,133,101,131,116,111,84,137,115,122,106,144,109,123,116,111,111,133,150,134,76,104] 
# print(len(times))
plt.figure(figsize=(20,8), dpi=80)
# Set bin width
distance = 2
# Calculate number of bins
group_num = int((max(times) - min(times)) / distance)
plt.hist(times, bins=group_num)

plt.xticks(range(min(times), max(times))[::2])
plt.grid(linestyle='--', alpha=0.5)
plt.xlabel('Movie Duration')
plt.ylabel('Number of Movies')
plt.show()

# %%
size = [55, 35, 10]  # Sizes of each part

plt.figure(figsize=(20,8), dpi=100)

label_list = ['Part 1', 'Part 2', 'Part 3'] # Labels for each part
color = ['red', 'green', 'blue'] # Colors for each part
explode = [0, 0.05, 0] # Explosion offset for each part
patches, l_text, p_text = plt.pie(size,
                                  explode = explode,
                                  colors = color,
                                  labels = label_list,
                                  labeldistance=1.1,
                                  autopct='%1.1f%%',
                                  shadow=False,
                                  startangle=150,
                                  pctdistance=0.6)

for t in l_text:
    print(dir(t))
for t in p_text:
    t.set_size(18)
for i in patches:
    i.set_color('pink')
    break

plt.legend()
plt.show()
# Out:
# ['_PROPERTIES_EXCLUDED_FROM_SET', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_agg_filter', '_alias_map', '_alpha', '_animated', '_antialiased', '_axes', '_bbox_patch', '_callbacks', '_char_index_at', '_charsize_cache', '_clipon', '_clippath', '_cm_set', '_color', '_different_canvas', '_fontproperties', '_fully_clipped_to_axes', '_get_dist_to_box', '_get_layout', '_get_multialignment', '_get_rendered_text_width', '_get_wrap_line_width', '_get_wrapped_text', '_get_xy_display', '_gid', '_horizontalalignment', '_in_layout', '_internal_update', '_label', '_linespacing', '_mouseover', '_multialignment', '_parse_math', '_path_effects', '_picker', '_preprocess_math', '_rasterized
# ...
